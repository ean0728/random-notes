# %%
import os
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage


llm = ChatOpenAI(
    api_key=os.getenv("API_KEY"),
    base_url=os.getenv("BASE_URL"),
    model="deepseek-chat",
    temperature=0.1,
)

def run_reflection_loop():
    """
    演示多步AI反思循环, 逐步优化Python函数
    """
    # 核心人物
    task_prompt = """
    你的任务是创建一个名为 `calculate_factorial` 的 Python 函数。
    该函数需满足以下要求:
    1. 只接受一个整数参数 n。
    2. 计算其阶乘(n!)。
    3. 包含清晰的 docstring,说明函数功能。
    4. 处理边界情况:0 的阶乘为 1。
    5. 处理无效输入:若输入为负数则抛出 ValueError。
    """
    # 反思循环
    max_iterations = 3
    current_code = ""
    # 构建对话历史， 为每步提供上下文
    message_history = [HumanMessage(content=task_prompt)]

    for i in range(max_iterations):
        print("\n" + "="*25 + f" 反思循环:第 {i + 1} 次迭代 " + "="*25)
        # 生成/优化阶段
        # 首次迭代为生成， 后续为优化
        if i == 0:
            print("\n>>> 阶段 1:生成初始代码...")
            # 首条消息为任务提示
            response = llm.invoke(message_history)
            current_code = response.content
        else:
            print("\n>>> 阶段 1:根据批判优化代码...")
            # 消息历史包含任务、上次代码和批判
            # 指示模型应用批判意见优化代码
            message_history.append(HumanMessage(content="请根据批判意见优化代码。"))
            response = llm.invoke(message_history)
            current_code = response.content
    
        print("\n‐‐‐ 生成代码(第 " + str(i + 1) + " 版) ‐‐‐\n" + current_code)
        message_history.append(response) # 将生成代码加入历史

        # 反思阶段
        print("\n>>> 阶段 2:对生成代码进行反思...")

        # 为批判者 Agent 创建专用提示
        # 要求模型以资深代码审查员身份批判代码
        reflector_prompt = [
            SystemMessage(content="""
            你是一名资深软件工程师,精通 Python。
            你的职责是对提供的 Python 代码进行细致代码审查。
            请根据原始任务要求,严格评估代码。
            检查是否有 bug、风格问题、遗漏边界情况及其他可改进之处。
            若代码完美且满足所有要求,仅回复 'CODE_IS_PERFECT'。
            否则,请以项目符号列表形式给出批判意见。
            """),
            HumanMessage(content=f"原始任务:\n{task_prompt}\n\n待审查代码:\n{current_code}"),
        ]

        critique_response = llm.invoke(reflector_prompt)
        critique = critique_response.content

        # 3.停止条件
        if "CODE_IS_PERFECT" in critique:
            print("\n‐‐‐ 批判 ‐‐‐\n 未发现进一步批判,代码已达要求。")
            break

        print("\n‐‐‐ 批判 ‐‐‐\n" + critique)
        # 将批判意见加入历史,供下轮优化使用
        message_history.append(HumanMessage(content=f"上次代码批判意见:\n{critique}"))

    print("\n" + "="*30 + " 最终结果 " + "="*30)
    print("\n 反思流程优化后的最终代码:\n")
    print(current_code)

if __name__ == "__main__":
    run_reflection_loop()
# Out:
# ========================= 反思循环:第 1 次迭代 =========================
#
# >>> 阶段 1:生成初始代码...
#
# ‐‐‐ 生成代码(第 1 版) ‐‐‐
# ```python
# def calculate_factorial(n: int) -> int:
#     """
#     计算非负整数 n 的阶乘 (n!)。
#
#     阶乘定义为 n! = n × (n-1) × (n-2) × ... × 1，特别地，0! = 1。
#
#     参数:
#     n (int): 要计算阶乘的非负整数。
#
#     返回:
#     int: n 的阶乘结果。
#
#     异常:
#     ValueError: 如果 n 是负数。
#
#     示例:
#     >>> calculate_factorial(5)
#     120
#     >>> calculate_factorial(0)
#     1
#     """
#     if n < 0:
#         raise ValueError("阶乘仅对非负整数定义，输入不能为负数。")
#
#     result = 1
#     for i in range(2, n + 1):
#         result *= i
#     return result
#
#
# # 测试示例
# if __name__ == "__main__":
#     # 正常情况测试
#     print(calculate_factorial(5))  # 输出: 120
#     print(calculate_factorial(0))  # 输出: 1
#     print(calculate_factorial(1))  # 输出: 1
#
#     # 异常情况测试
#     try:
#         calculate_factorial(-3)
#     except ValueError as e:
#         print(f"捕获到预期异常: {e}")  # 输出: 捕获到预期异常: 阶乘仅对非负整数定义，输入不能为负数。
# ```
#
# >>> 阶段 2:对生成代码进行反思...
#
# ‐‐‐ 批判 ‐‐‐
# - **类型提示不完整**: 函数签名中的类型提示 `-> int` 对于较大的 `n` 值可能不准确，因为 Python 的 `int` 类型可以处理任意大的整数，但阶乘结果增长极快，对于非常大的 `n`，结果可能超出典型整数范围（尽管 Python 会处理大整数）。这更多是一个潜在的性能/内存考虑，但类型提示本身是技术上正确的，因为 Python 的 `int` 是任意精度的。然而，对于非常大的 `n`，阶乘结果可能变得不切实际地大，导致内存或性能问题。建议在 docstring 中添加注释，说明函数适用于较小的 `n` 值，或考虑使用 `math.factorial` 作为替代（但根据任务要求，需要自定义实现）。这不是一个错误，但可视为一个改进点。
#
# - **循环效率可优化**: 当前循环从 `2` 开始到 `n + 1`，对于 `n = 0` 或 `n = 1`，`range(2, n + 1)` 是空的（例如 `range(2, 1)`），因此 `result` 保持为 `1`，这正确地处理了边界情况。但循环可以更简洁地写为 `for i in range(1, n + 1):` 并从 `result = 1` 开始，这样逻辑更直观。不过，当前实现避免了不必要的迭代（对于 `n=0` 或 `1`，不进入循环），因此是高效的。这不是一个错误，但可读性稍差。
#
# - **缺少输入类型验证**: 函数使用类型提示 `n: int`，但 Python 是动态类型语言，如果传入非整数（如浮点数或字符串），函数可能引发 `TypeError`（例如在 `n < 0` 比较中）或行为异常。任务要求只接受整数参数，但代码未显式检查类型。建议添加类型检查，例如 `if not isinstance(n, int): raise TypeError("n 必须是整数")`。然而，类型提示在静态类型检查工具中会捕获此问题，但运行时可能失败。根据任务严格性，这可以视为一个遗漏。
#
# - **测试代码中的潜在问题**: 在 `if __name__ == "__main__":` 块中，测试代码打印异常消息，但未验证输出是否与预期匹配（例如使用 `assert` 语句）。这更多是测试完整性问题，不影响函数本身，但建议添加断言以确保正确性。例如：`assert calculate_factorial(5) == 120`。
#
# - **docstring 中的示例未使用 doctest 格式**: docstring 包含示例，但未格式化为可运行的 doctest（例如缺少 `>>>` 前缀后的输出）。当前示例是文本描述，但可以改进为使用 Python 的 doctest 模块标准格式。不过，这更多是文档风格问题，不影响功能。
#
# - **大整数处理未明确**: 对于非常大的 `n`，阶乘结果可能超出 Python 整数表示范围（尽管 Python 支持大整数，但计算可能非常慢或消耗大量内存）。函数未在 docstring 中警告此限制。建议添加注释，说明函数适用于较小的 `n` 值（例如 `n <= 20` 以保持结果在 64 位范围内，或更高但需注意性能）。
#
# 尽管存在上述改进点，代码整体满足任务要求：函数正确计算阶乘、处理边界情况（0! = 1）、抛出 `ValueError` 对于负数、包含清晰 docstring。主要问题是缺少输入类型验证，这可能导致非整数输入时未定义行为。因此，代码不完美。
#
# ========================= 反思循环:第 2 次迭代 =========================
#
# >>> 阶段 1:根据批判优化代码...
#
# ‐‐‐ 生成代码(第 2 版) ‐‐‐
# ```python
# def calculate_factorial(n: int) -> int:
#     """
#     计算非负整数 n 的阶乘 (n!)。
#
#     阶乘定义为 n! = n × (n-1) × (n-2) × ... × 1，特别地，0! = 1。
#
#     注意：
#     - 对于较大的 n 值（如 n > 20），结果可能非常大，计算时间和内存消耗会显著增加。
#     - 对于非常大的 n，建议使用 math.factorial() 或考虑性能优化方案。
#
#     参数:
#     n (int): 要计算阶乘的非负整数。
#
#     返回:
#     int: n 的阶乘结果。
#
#     异常:
#     TypeError: 如果 n 不是整数。
#     ValueError: 如果 n 是负数。
#
#     示例:
#     >>> calculate_factorial(5)
#     120
#     >>> calculate_factorial(0)
#     1
#     >>> calculate_factorial(1)
#     1
#     """
#     # 输入类型验证
#     if not isinstance(n, int):
#         raise TypeError("参数 n 必须是整数类型")
#
#     # 边界情况处理
#     if n < 0:
#         raise ValueError("阶乘仅对非负整数定义，输入不能为负数。")
#
#     # 优化循环：从 1 到 n，更直观
#     result = 1
#     for i in range(1, n + 1):
#         result *= i
#     return result
#
#
# # 测试代码
# if __name__ == "__main__":
#     # 正常情况测试
#     assert calculate_factorial(5) == 120, "5的阶乘应为120"
#     assert calculate_factorial(0) == 1, "0的阶乘应为1"
#     assert calculate_factorial(1) == 1, "1的阶乘应为1"
#     assert calculate_factorial(10) == 3628800, "10的阶乘应为3628800"
#
#     print("所有正常测试通过！")
#
#     # 异常情况测试
#     try:
#         calculate_factorial(-3)
#         assert False, "负数应抛出ValueError"
#     except ValueError as e:
#         print(f"负数测试通过: {e}")
#
#     try:
#         calculate_factorial(3.5)
#         assert False, "浮点数应抛出TypeError"
#     except TypeError as e:
#         print(f"浮点数测试通过: {e}")
#
#     try:
#         calculate_factorial("5")
#         assert False, "字符串应抛出TypeError"
#     except TypeError as e:
#         print(f"字符串测试通过: {e}")
#
#     print("所有异常测试通过！")
#
#     # 性能提示
#     print("\n注意：对于 n > 20，结果会非常大，请谨慎使用。")
# ```
#
# ## 主要改进点：
#
# 1. **添加了完整的类型验证**：
#    - 使用 `isinstance(n, int)` 检查输入是否为整数
#    - 对于非整数输入，抛出 `TypeError` 并提供清晰的错误信息
#
# 2. **优化了循环逻辑**：
#    - 将循环改为 `for i in range(1, n + 1):`
#    - 这样对于 n=0 或 n=1，循环仍然会执行（但只执行一次），逻辑更直观
#    - 保持了相同的正确性和效率
#
# 3. **增强了 docstring**：
#    - 添加了关于大整数处理的警告
#    - 完善了异常说明
#    - 格式化了示例，使其符合 doctest 格式
#
# 4. **改进了测试代码**：
#    - 使用 `assert` 语句验证结果
#    - 添加了更多测试用例
#    - 对异常情况也使用断言验证
#    - 添加了性能提示
#
# 5. **添加了类型安全**：
#    - 确保函数只接受整数参数
#    - 防止了因类型错误导致的意外行为
#
# 这个版本更加健壮，能够正确处理各种边界情况和异常输入，同时保持了代码的清晰性和可读性。
#
# >>> 阶段 2:对生成代码进行反思...
#
# ‐‐‐ 批判 ‐‐‐
#  未发现进一步批判,代码已达要求。
#
# ============================== 最终结果 ==============================
#
#  反思流程优化后的最终代码:
#
# ```python
# def calculate_factorial(n: int) -> int:
#     """
#     计算非负整数 n 的阶乘 (n!)。
#
#     阶乘定义为 n! = n × (n-1) × (n-2) × ... × 1，特别地，0! = 1。
#
#     注意：
#     - 对于较大的 n 值（如 n > 20），结果可能非常大，计算时间和内存消耗会显著增加。
#     - 对于非常大的 n，建议使用 math.factorial() 或考虑性能优化方案。
#
#     参数:
#     n (int): 要计算阶乘的非负整数。
#
#     返回:
#     int: n 的阶乘结果。
#
#     异常:
#     TypeError: 如果 n 不是整数。
#     ValueError: 如果 n 是负数。
#
#     示例:
#     >>> calculate_factorial(5)
#     120
#     >>> calculate_factorial(0)
#     1
#     >>> calculate_factorial(1)
#     1
#     """
#     # 输入类型验证
#     if not isinstance(n, int):
#         raise TypeError("参数 n 必须是整数类型")
#
#     # 边界情况处理
#     if n < 0:
#         raise ValueError("阶乘仅对非负整数定义，输入不能为负数。")
#
#     # 优化循环：从 1 到 n，更直观
#     result = 1
#     for i in range(1, n + 1):
#         result *= i
#     return result
#
#
# # 测试代码
# if __name__ == "__main__":
#     # 正常情况测试
#     assert calculate_factorial(5) == 120, "5的阶乘应为120"
#     assert calculate_factorial(0) == 1, "0的阶乘应为1"
#     assert calculate_factorial(1) == 1, "1的阶乘应为1"
#     assert calculate_factorial(10) == 3628800, "10的阶乘应为3628800"
#
#     print("所有正常测试通过！")
#
#     # 异常情况测试
#     try:
#         calculate_factorial(-3)
#         assert False, "负数应抛出ValueError"
#     except ValueError as e:
#         print(f"负数测试通过: {e}")
#
#     try:
#         calculate_factorial(3.5)
#         assert False, "浮点数应抛出TypeError"
#     except TypeError as e:
#         print(f"浮点数测试通过: {e}")
#
#     try:
#         calculate_factorial("5")
#         assert False, "字符串应抛出TypeError"
#     except TypeError as e:
#         print(f"字符串测试通过: {e}")
#
#     print("所有异常测试通过！")
#
#     # 性能提示
#     print("\n注意：对于 n > 20，结果会非常大，请谨慎使用。")
# ```
#
# ## 主要改进点：
#
# 1. **添加了完整的类型验证**：
#    - 使用 `isinstance(n, int)` 检查输入是否为整数
#    - 对于非整数输入，抛出 `TypeError` 并提供清晰的错误信息
#
# 2. **优化了循环逻辑**：
#    - 将循环改为 `for i in range(1, n + 1):`
#    - 这样对于 n=0 或 n=1，循环仍然会执行（但只执行一次），逻辑更直观
#    - 保持了相同的正确性和效率
#
# 3. **增强了 docstring**：
#    - 添加了关于大整数处理的警告
#    - 完善了异常说明
#    - 格式化了示例，使其符合 doctest 格式
#
# 4. **改进了测试代码**：
#    - 使用 `assert` 语句验证结果
#    - 添加了更多测试用例
#    - 对异常情况也使用断言验证
#    - 添加了性能提示
#
# 5. **添加了类型安全**：
#    - 确保函数只接受整数参数
#    - 防止了因类型错误导致的意外行为
#
# 这个版本更加健壮，能够正确处理各种边界情况和异常输入，同时保持了代码的清晰性和可读性。
